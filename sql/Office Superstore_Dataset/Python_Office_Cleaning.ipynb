# %%
#this project was challenge for myself in python (extract dataset, cleaning, load to sql) and SQL (connect with pyhon, analyze data)

# %%
#install kaggle library
pip install kaggle
# Out:
# Requirement already satisfied: kaggle in c:\users\zakym_xg1tqji\anaconda3\lib\site-packages (1.8.4)
# Requirement already satisfied: bleach in c:\users\zakym_xg1tqji\anaconda3\lib\site-packages (from kaggle) (6.2.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.15 in c:\users\zakym_xg1tqji\anaconda3\lib\site-packages (from kaggle) (0.1.15)
# Requirement already satisfied: packaging in c:\users\zakym_xg1tqji\anaconda3\lib\site-packages (from kaggle) (24.2)
# Requirement already satisfied: protobuf in c:\users\zakym_xg1tqji\anaconda3\lib\site-packages (from kaggle) (5.29.3)
# Requirement already satisfied: python-dateutil in c:\users\zakym_xg1tqji\anaconda3\lib\site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in c:\users\zakym_xg1tqji\anaconda3\lib\site-packages (from kaggle) (5.0.2)
# Requirement already satisfied: requests in c:\users\zakym_xg1tqji\anaconda3\lib\site-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\zakym_xg1tqji\anaconda3\lib\site-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in c:\users\zakym_xg1tqji\anaconda3\lib\site-packages (from kaggle) (2.3.0)
# Requirement already satisfied: webencodings in c:\users\zakym_xg1tqji\anaconda3\lib\site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: six>=1.5 in c:\users\zakym_xg1tqji\anaconda3\lib\site-packages (from python-dateutil->kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\zakym_xg1tqji\anaconda3\lib\site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\zakym_xg1tqji\anaconda3\lib\site-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\zakym_xg1tqji\anaconda3\lib\site-packages (from requests->kaggle) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\zakym_xg1tqji\anaconda3\lib\site-packages (from requests->kaggle) (2025.4.26)
# Requirement already satisfied: colorama in c:\users\zakym_xg1tqji\anaconda3\lib\site-packages (from tqdm->kaggle) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
#connect to kaggle via token
import os
os.environ["KAGGLE_API_TOKEN"] = "KGAT_4287f54fae767c097934618e585cc9a8"

# %%
#retrieve kaggle dataset
# !kaggle datasets list -s ankitbansal06
# Out:
# ref                          title                size  lastUpdated                 downloadCount  voteCount  usabilityRating
# ---------------------------  -------------  ----------  --------------------------  -------------  ---------  ---------------
# ankitbansal06/retail-orders  Retail Orders      205161  2024-04-13 08:31:36.377000          28090         44  0.47058824

# %%
#download dataset and unzip
# !kaggle datasets download ankitbansal06/retail-orders -f orders.csv --unzip

##appearently, file fail to unzip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# License(s): CC0-1.0
# Downloading orders.csv.zip to C:\Users\zakym_xg1tqji\Documents\Path to Data Analyst\SQL\Project
#   0%|          | 0.00/200k [00:00<?, ?B/s]
# 100%|##########| 200k/200k [00:00<00:00, 308kB/s]
# 100%|##########| 200k/200k [00:00<00:00, 307kB/s]

# %%
#unzip file
import zipfile

zipref = zipfile.ZipFile('orders.csv.zip')
zipref.extractall()

# %%
#read the data, quick check
import pandas as pd

df=pd.read_csv("orders.csv")
df.head(50)
# Out:
#     Order Id  Order Date       Ship Mode      Segment        Country  \
# 0          1  2023-03-01    Second Class     Consumer  United States
# 1          2  2023-08-15    Second Class     Consumer  United States
# 2          3  2023-01-10    Second Class    Corporate  United States
# 3          4  2022-06-18  Standard Class     Consumer  United States
# 4          5  2022-07-13  Standard Class     Consumer  United States
# 5          6  2022-03-13   Not Available     Consumer  United States
# 6          7  2022-12-28  Standard Class     Consumer  United States
# 7          8  2022-01-25  Standard Class     Consumer  United States
# 8          9  2023-03-23   Not Available     Consumer  United States
# 9         10  2023-05-16  Standard Class     Consumer  United States
# 10        11  2023-03-31   Not Available     Consumer  United States
# 11        12  2023-12-25   Not Available     Consumer  United States
# 12        13  2022-02-11  Standard Class     Consumer  United States
# 13        14  2023-07-18  Standard Class     Consumer  United States
# 14        15  2023-11-09         unknown  Home Office  United States
# 15        16  2022-06-18  Standard Class  Home Office  United States
# 16        17  2022-02-04  Standard Class     Consumer  United States
# 17        18  2023-08-04    Second Class     Consumer  United States
# 18        19  2022-01-23    Second Class     Consumer  United States
# 19        20  2022-01-11    Second Class     Consumer  United States
# 20        21  2022-10-05    Second Class     Consumer  United States
# 21        22  2023-07-16  Standard Class    Corporate  United States
# 22        23  2023-05-06  Standard Class    Corporate  United States
# 23        24  2023-05-21    Second Class     Consumer  United States
# 24        25  2023-02-24  Standard Class     Consumer  United States
# 25        26  2022-06-20    Second Class     Consumer  United States
# 26        27  2022-02-08    Second Class     Consumer  United States
# 27        28  2023-12-11  Standard Class     Consumer  United States
# 28        29  2022-08-21  Standard Class     Consumer  United States
# 29        30  2022-08-14  Standard Class     Consumer  United States
# 30        31  2022-11-20  Standard Class     Consumer  United States
# 31        32  2023-01-19  Standard Class     Consumer  United States
# 32        33  2023-01-30  Standard Class     Consumer  United States
# 33        34  2022-06-03  Standard Class     Consumer  United States
# 34        35  2022-09-28    Second Class  Home Office  United States
# 35        36  2022-10-30     First Class    Corporate  United States
# 36        37  2023-07-27     First Class    Corporate  United States
# 37        38  2023-03-07  Standard Class  Home Office  United States
# 38        39  2023-08-18  Standard Class  Home Office  United States
# 39        40  2022-01-20  Standard Class  Home Office  United States
# 40        41  2023-06-29  Standard Class  Home Office  United States
# 41        42  2022-06-28  Standard Class    Corporate  United States
# 42        43  2023-02-09  Standard Class    Corporate  United States
# 43        44  2023-09-18  Standard Class    Corporate  United States
# 44        45  2022-11-11     First Class    Corporate  United States
# 45        46  2022-05-27     First Class    Corporate  United States
# 46        47  2023-02-03    Second Class     Consumer  United States
# 47        48  2022-02-16  Standard Class     Consumer  United States
# 48        49  2022-05-06  Standard Class     Consumer  United States
# 49        50  2023-06-18  Standard Class     Consumer  United States
#
#                City           State  Postal Code   Region         Category  \
# 0         Henderson        Kentucky        42420    South        Furniture
# 1         Henderson        Kentucky        42420    South        Furniture
# 2       Los Angeles      California        90036     West  Office Supplies
# 3   Fort Lauderdale         Florida        33311    South        Furniture
# 4   Fort Lauderdale         Florida        33311    South  Office Supplies
# 5       Los Angeles      California        90032     West        Furniture
# 6       Los Angeles      California        90032     West  Office Supplies
# 7       Los Angeles      California        90032     West       Technology
# 8       Los Angeles      California        90032     West  Office Supplies
# 9       Los Angeles      California        90032     West  Office Supplies
# 10      Los Angeles      California        90032     West        Furniture
# 11      Los Angeles      California        90032     West       Technology
# 12          Concord  North Carolina        28027    South  Office Supplies
# 13          Seattle      Washington        98103     West  Office Supplies
# 14       Fort Worth           Texas        76106  Central  Office Supplies
# 15       Fort Worth           Texas        76106  Central  Office Supplies
# 16          Madison       Wisconsin        53711  Central  Office Supplies
# 17      West Jordan            Utah        84084     West  Office Supplies
# 18    San Francisco      California        94109     West  Office Supplies
# 19    San Francisco      California        94109     West       Technology
# 20    San Francisco      California        94109     West  Office Supplies
# 21          Fremont        Nebraska        68025  Central  Office Supplies
# 22          Fremont        Nebraska        68025  Central  Office Supplies
# 23     Philadelphia    Pennsylvania        19140     East        Furniture
# 24             Orem            Utah        84057     West        Furniture
# 25      Los Angeles      California        90049     West  Office Supplies
# 26      Los Angeles      California        90049     West       Technology
# 27     Philadelphia    Pennsylvania        19140     East        Furniture
# 28     Philadelphia    Pennsylvania        19140     East  Office Supplies
# 29     Philadelphia    Pennsylvania        19140     East        Furniture
# 30     Philadelphia    Pennsylvania        19140     East  Office Supplies
# 31     Philadelphia    Pennsylvania        19140     East  Office Supplies
# 32     Philadelphia    Pennsylvania        19140     East  Office Supplies
# 33     Philadelphia    Pennsylvania        19140     East  Office Supplies
# 34          Houston           Texas        77095  Central  Office Supplies
# 35       Richardson           Texas        75080  Central       Technology
# 36       Richardson           Texas        75080  Central        Furniture
# 37          Houston           Texas        77041  Central  Office Supplies
# 38          Houston           Texas        77041  Central        Furniture
# 39          Houston           Texas        77041  Central        Furniture
# 40          Houston           Texas        77041  Central       Technology
# 41       Naperville        Illinois        60540  Central       Technology
# 42      Los Angeles      California        90049     West  Office Supplies
# 43        Melbourne         Florida        32935    South  Office Supplies
# 44            Eagan       Minnesota        55122  Central       Technology
# 45            Eagan       Minnesota        55122  Central  Office Supplies
# 46         Westland        Michigan        48185  Central  Office Supplies
# 47            Dover        Delaware        19901     East       Technology
# 48            Dover        Delaware        19901     East       Technology
# 49       New Albany         Indiana        47150  Central  Office Supplies
#
#    Sub Category       Product Id  cost price  List Price  Quantity  \
# 0     Bookcases  FUR-BO-10001798         240         260         2
# 1        Chairs  FUR-CH-10000454         600         730         3
# 2        Labels  OFF-LA-10000240          10          10         2
# 3        Tables  FUR-TA-10000577         780         960         5
# 4       Storage  OFF-ST-10000760          20          20         2
# 5   Furnishings  FUR-FU-10001487          50          50         7
# 6           Art  OFF-AR-10002833          10          10         4
# 7        Phones  TEC-PH-10002275         860         910         6
# 8       Binders  OFF-BI-10003910          20          20         3
# 9    Appliances  OFF-AP-10002892          90         110         5
# 10       Tables  FUR-TA-10001539        1470        1710         9
# 11       Phones  TEC-PH-10002033         750         910         4
# 12        Paper  OFF-PA-10002365          20          20         3
# 13      Binders  OFF-BI-10003656         360         410         3
# 14   Appliances  OFF-AP-10002311          60          70         5
# 15      Binders  OFF-BI-10000756           0           0         3
# 16      Storage  OFF-ST-10004186         610         670         6
# 17      Storage  OFF-ST-10000107          60          60         2
# 18          Art  OFF-AR-10003056          10          10         2
# 19       Phones  TEC-PH-10001949         170         210         3
# 20      Binders  OFF-BI-10002215          20          20         4
# 21          Art  OFF-AR-10000246          20          20         7
# 22   Appliances  OFF-AP-10001492          50          60         7
# 23       Chairs  FUR-CH-10002774          60          70         2
# 24       Tables  FUR-TA-10000577         900        1040         3
# 25      Binders  OFF-BI-10001634          10          10         2
# 26  Accessories  TEC-AC-10003027          80          90         3
# 27    Bookcases  FUR-BO-10004834        2740        3080         7
# 28      Binders  OFF-BI-10000474          10          10         2
# 29  Furnishings  FUR-FU-10004848         100         120         3
# 30    Envelopes  OFF-EN-10001509           0           0         2
# 31          Art  OFF-AR-10004042          70          90         6
# 32      Binders  OFF-BI-10001525          10          10         6
# 33          Art  OFF-AR-10001683          20          20         2
# 34        Paper  OFF-PA-10000249          30          30         3
# 35       Phones  TEC-PH-10004977        1020        1100         7
# 36  Furnishings  FUR-FU-10003664         180         190         5
# 37    Envelopes  OFF-EN-10002986          90         110         9
# 38    Bookcases  FUR-BO-10002545         460         530         3
# 39       Chairs  FUR-CH-10004218         200         210         3
# 40       Phones  TEC-PH-10000486         350         370         4
# 41       Phones  TEC-PH-10004093         140         150         4
# 42      Storage  OFF-ST-10003479          70          80         2
# 43      Storage  OFF-ST-10003282          90         100         2
# 44  Accessories  TEC-AC-10000171          40          50         2
# 45      Binders  OFF-BI-10003291          20          20         2
# 46      Storage  OFF-ST-10001713         180         210         4
# 47  Accessories  TEC-AC-10002167          50          50         3
# 48       Phones  TEC-PH-10003988          20          20         2
# 49      Binders  OFF-BI-10004410          30          40         6
#
#     Discount Percent
# 0                  2
# 1                  3
# 2                  5
# 3                  2
# 4                  5
# 5                  3
# 6                  3
# 7                  5
# 8                  2
# 9                  3
# 10                 3
# 11                 3
# 12                 3
# 13                 2
# 14                 5
# 15                 5
# 16                 3
# 17                 4
# 18                 4
# 19                 3
# 20                 2
# 21                 4
# 22                 3
# 23                 4
# 24                 5
# 25                 5
# 26                 3
# 27                 3
# 28                 5
# 29                 4
# 30                 5
# 31                 4
# 32                 5
# 33                 4
# 34                 3
# 35                 5
# 36                 4
# 37                 2
# 38                 2
# 39                 2
# 40                 5
# 41                 3
# 42                 5
# 43                 4
# 44                 2
# 45                 5
# 46                 4
# 47                 5
# 48                 4
# 49                 4

# %%
#rename columns name
df.columns=df.columns.str.lower().str.replace(' ', '_')
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_mode', 'segment', 'country', 'city',
#        'state', 'postal_code', 'region', 'category', 'sub_category',
#        'product_id', 'cost_price', 'list_price', 'quantity',
#        'discount_percent'],
#       dtype='object')

# %%
#check null existance
df.isnull().sum()

##found null value and unstandardize value from quick check
# Out:
# order_id            0
# order_date          0
# ship_mode           1
# segment             0
# country             0
# city                0
# state               0
# postal_code         0
# region              0
# category            0
# sub_category        0
# product_id          0
# cost_price          0
# list_price          0
# quantity            0
# discount_percent    0
# dtype: int64

# %%
#spotting null value
df[df.isnull().any(axis=1)]
# Out:
#      order_id  order_date ship_mode    segment        country     city  \
# 118       119  2023-07-19       NaN  Corporate  United States  Bristol
#
#          state  postal_code region         category sub_category  \
# 118  Tennessee        37620  South  Office Supplies      Binders
#
#           product_id  cost_price  list_price  quantity  discount_percent
# 118  OFF-BI-10003650         140         160         1                 5

# %%
#spotting unstandardized value
df['ship_mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'Not Available', 'unknown',
#        'First Class', nan, 'Same Day'], dtype=object)

# %%
#null-if unstandardized value
df['ship_mode']=df['ship_mode'].replace(['Not Available', 'unknown'], pd.NA)
df['ship_mode'].unique()

##NA for pandas and nan for numpy
##to uniforming null values, import numpy and turn those values into np.nan

# %%
#null check
df.isnull().sum()
# Out:
# order_id            0
# order_date          0
# ship_mode           6
# segment             0
# country             0
# city                0
# state               0
# postal_code         0
# region              0
# category            0
# sub_category        0
# product_id          0
# cost_price          0
# list_price          0
# quantity            0
# discount_percent    0
# dtype: int64

# %%
#inspect datatypes
df.dtypes

##found mismatch data type "order_date" as object rather than date
# Out:
# order_id              int64
# order_date           object
# ship_mode            object
# segment              object
# country              object
# city                 object
# state                object
# postal_code           int64
# region               object
# category             object
# sub_category         object
# product_id           object
# cost_price            int64
# list_price            int64
# quantity              int64
# discount_percent      int64
# discount            float64
# final_price         float64
# total_cost            int64
# net_revenue         float64
# profit              float64
# dtype: object

# %%
#converting to date
df['order_date']=pd.to_datetime(df['order_date'], format="%Y-%m-%d")
df.dtypes
# Out:
# order_id                     int64
# order_date          datetime64[ns]
# ship_mode                   object
# segment                     object
# country                     object
# city                        object
# state                       object
# postal_code                  int64
# region                      object
# category                    object
# sub_category                object
# product_id                  object
# cost_price                   int64
# list_price                   int64
# quantity                     int64
# discount_percent             int64
# discount                   float64
# final_price                float64
# total_cost                   int64
# net_revenue                float64
# profit                     float64
# dtype: object

# %%
#start working on the table
df.head()
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# 1       Chairs  FUR-CH-10000454         600         730         3
# 2       Labels  OFF-LA-10000240          10          10         2
# 3       Tables  FUR-TA-10000577         780         960         5
# 4      Storage  OFF-ST-10000760          20          20         2
#
#    discount_percent
# 0                 2
# 1                 3
# 2                 5
# 3                 2
# 4                 5

# %%
#gerate discount value
df['discount']=df['list_price']*df['discount_percent']*0.01
df
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# 1           Henderson    Kentucky        42420  South        Furniture
# 2         Los Angeles  California        90036   West  Office Supplies
# 3     Fort Lauderdale     Florida        33311  South        Furniture
# 4     Fort Lauderdale     Florida        33311  South  Office Supplies
# ...               ...         ...          ...    ...              ...
# 9989            Miami     Florida        33180  South        Furniture
# 9990       Costa Mesa  California        92627   West        Furniture
# 9991       Costa Mesa  California        92627   West       Technology
# 9992       Costa Mesa  California        92627   West  Office Supplies
# 9993      Westminster  California        92683   West  Office Supplies
#
#      sub_category       product_id  cost_price  list_price  quantity  \
# 0       Bookcases  FUR-BO-10001798         240         260         2
# 1          Chairs  FUR-CH-10000454         600         730         3
# 2          Labels  OFF-LA-10000240          10          10         2
# 3          Tables  FUR-TA-10000577         780         960         5
# 4         Storage  OFF-ST-10000760          20          20         2
# ...           ...              ...         ...         ...       ...
# 9989  Furnishings  FUR-FU-10001889          30          30         3
# 9990  Furnishings  FUR-FU-10000747          70          90         2
# 9991       Phones  TEC-PH-10003645         220         260         2
# 9992        Paper  OFF-PA-10004041          30          30         4
# 9993   Appliances  OFF-AP-10002684         210         240         2
#
#       discount_percent  discount
# 0                    2       5.2
# 1                    3      21.9
# 2                    5       0.5
# 3                    2      19.2
# 4                    5       1.0
# ...                ...       ...
# 9989                 4       1.2
# 9990                 4       3.6
# 9991                 2       5.2
# 9992                 3       0.9
# 9993                 3       7.2
#
# [9994 rows x 17 columns]

# %%
#generate final_price
df['final_price']=df['list_price']-df['discount']
df
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# 1           Henderson    Kentucky        42420  South        Furniture
# 2         Los Angeles  California        90036   West  Office Supplies
# 3     Fort Lauderdale     Florida        33311  South        Furniture
# 4     Fort Lauderdale     Florida        33311  South  Office Supplies
# ...               ...         ...          ...    ...              ...
# 9989            Miami     Florida        33180  South        Furniture
# 9990       Costa Mesa  California        92627   West        Furniture
# 9991       Costa Mesa  California        92627   West       Technology
# 9992       Costa Mesa  California        92627   West  Office Supplies
# 9993      Westminster  California        92683   West  Office Supplies
#
#      sub_category       product_id  cost_price  list_price  quantity  \
# 0       Bookcases  FUR-BO-10001798         240         260         2
# 1          Chairs  FUR-CH-10000454         600         730         3
# 2          Labels  OFF-LA-10000240          10          10         2
# 3          Tables  FUR-TA-10000577         780         960         5
# 4         Storage  OFF-ST-10000760          20          20         2
# ...           ...              ...         ...         ...       ...
# 9989  Furnishings  FUR-FU-10001889          30          30         3
# 9990  Furnishings  FUR-FU-10000747          70          90         2
# 9991       Phones  TEC-PH-10003645         220         260         2
# 9992        Paper  OFF-PA-10004041          30          30         4
# 9993   Appliances  OFF-AP-10002684         210         240         2
#
#       discount_percent  discount  final_price
# 0                    2       5.2        254.8
# 1                    3      21.9        708.1
# 2                    5       0.5          9.5
# 3                    2      19.2        940.8
# 4                    5       1.0         19.0
# ...                ...       ...          ...
# 9989                 4       1.2         28.8
# 9990                 4       3.6         86.4
# 9991                 2       5.2        254.8
# 9992                 3       0.9         29.1
# 9993                 3       7.2        232.8
#
# [9994 rows x 18 columns]

# %%
#generate total_cost, net_revenue, and profit
df['total_cost']=df['cost_price']*df['quantity']
df['net_revenue']=df['final_price']*df['quantity']
df['profit']=df['net_revenue']-df['total_cost']
df
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  ...  \
# 0           Henderson    Kentucky        42420  South        Furniture  ...
# 1           Henderson    Kentucky        42420  South        Furniture  ...
# 2         Los Angeles  California        90036   West  Office Supplies  ...
# 3     Fort Lauderdale     Florida        33311  South        Furniture  ...
# 4     Fort Lauderdale     Florida        33311  South  Office Supplies  ...
# ...               ...         ...          ...    ...              ...  ...
# 9989            Miami     Florida        33180  South        Furniture  ...
# 9990       Costa Mesa  California        92627   West        Furniture  ...
# 9991       Costa Mesa  California        92627   West       Technology  ...
# 9992       Costa Mesa  California        92627   West  Office Supplies  ...
# 9993      Westminster  California        92683   West  Office Supplies  ...
#
#            product_id cost_price  list_price  quantity  discount_percent  \
# 0     FUR-BO-10001798        240         260         2                 2
# 1     FUR-CH-10000454        600         730         3                 3
# 2     OFF-LA-10000240         10          10         2                 5
# 3     FUR-TA-10000577        780         960         5                 2
# 4     OFF-ST-10000760         20          20         2                 5
# ...               ...        ...         ...       ...               ...
# 9989  FUR-FU-10001889         30          30         3                 4
# 9990  FUR-FU-10000747         70          90         2                 4
# 9991  TEC-PH-10003645        220         260         2                 2
# 9992  OFF-PA-10004041         30          30         4                 3
# 9993  OFF-AP-10002684        210         240         2                 3
#
#       discount  final_price  total_cost  net_revenue  profit
# 0          5.2        254.8         480        509.6    29.6
# 1         21.9        708.1        1800       2124.3   324.3
# 2          0.5          9.5          20         19.0    -1.0
# 3         19.2        940.8        3900       4704.0   804.0
# 4          1.0         19.0          40         38.0    -2.0
# ...        ...          ...         ...          ...     ...
# 9989       1.2         28.8          90         86.4    -3.6
# 9990       3.6         86.4         140        172.8    32.8
# 9991       5.2        254.8         440        509.6    69.6
# 9992       0.9         29.1         120        116.4    -3.6
# 9993       7.2        232.8         420        465.6    45.6
#
# [9994 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_mode', 'segment', 'country', 'city',
#        'state', 'postal_code', 'region', 'category', 'sub_category',
#        'product_id', 'cost_price', 'list_price', 'quantity',
#        'discount_percent', 'discount', 'final_price', 'total_cost',
#        'net_revenue', 'profit'],
#       dtype='object')

# %%
#load clean dataset to SQL, import tools
# !pip install psycopg2-binary sqlalchemy
from sqlalchemy import create_engine

##for convenience, prepared existing blank table in SQL already
# Out:
# Requirement already satisfied: psycopg2-binary in c:\users\zakym_xg1tqji\anaconda3\lib\site-packages (2.9.11)
# Requirement already satisfied: sqlalchemy in c:\users\zakym_xg1tqji\anaconda3\lib\site-packages (2.0.39)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\zakym_xg1tqji\anaconda3\lib\site-packages (from sqlalchemy) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\zakym_xg1tqji\anaconda3\lib\site-packages (from sqlalchemy) (4.12.2)

# %%
#create connection to PostgreSQL and connect it
engine = create_engine(
    "postgresql+psycopg2://postgres:datadriven@localhost:5432/retail_db"
)

engine.connect()

##syntax "postgresql+psycopg2://user:yourpassword@yourhost:yourserver/yourexistingdb"

# %%
#check the connection
pd.read_sql("SELECT 1;", engine)

##appearing 1 means connected
# Out:
#    ?column?
# 0         1

# %%
#export dataset to predefined SQL table
df.to_sql(
    name="retail_orders",
    con=engine,
    if_exists="append",
    index=False
)
# Out:
# 994

# %%
#test the result and connection
pd.read_sql("SELECT * FROM retail_orders LIMIT 5;", engine)
 
##if the result is correctly appeared, the export success
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state postal_code region         category  ...  \
# 0        Henderson    Kentucky       42420  South        Furniture  ...
# 1        Henderson    Kentucky       42420  South        Furniture  ...
# 2      Los Angeles  California       90036   West  Office Supplies  ...
# 3  Fort Lauderdale     Florida       33311  South        Furniture  ...
# 4  Fort Lauderdale     Florida       33311  South  Office Supplies  ...
#
#         product_id cost_price  list_price  quantity  discount_percent  \
# 0  FUR-BO-10001798      240.0       260.0         2               2.0
# 1  FUR-CH-10000454      600.0       730.0         3               3.0
# 2  OFF-LA-10000240       10.0        10.0         2               5.0
# 3  FUR-TA-10000577      780.0       960.0         5               2.0
# 4  OFF-ST-10000760       20.0        20.0         2               5.0
#
#    discount  final_price  total_cost  net_revenue  profit
# 0       5.2        254.8       480.0        509.6    29.6
# 1      21.9        708.1      1800.0       2124.3   324.3
# 2       0.5          9.5        20.0         19.0    -1.0
# 3      19.2        940.8      3900.0       4704.0   804.0
# 4       1.0         19.0        40.0         38.0    -2.0
#
# [5 rows x 21 columns]

# %%
#continue the work on PostgreSQL
